# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import json
import time
import datetime as dt
import re

# %%
# Dealers description
dealer_dct = {
    'id': 'tabangimotors',
    'name': 'Tabangi Motors',
    'street': '5926 Shawson Dr',
    'city': 'Mississauga',
    'zip': 'L4W 3W5',
    'province': 'ON',
    'phone': '905-670-3738',
    'url': 'https://www.tabangimotors.com',
    'latitude': '43.646760',
    'longitude': '-79.645490'
}

print(json.dumps(dealer_dct, indent=4))

with open('data/tabangimotors.json', 'w', encoding='utf-8') as fp:
    fp.writelines(json.dumps(dealer_dct) + "\n")
# Out:
# {
#     "id": "simpleautos",
#     "name": "Simple Auto",
#     "street": "2829 Derry Rd E.",
#     "city": "Mississauga",
#     "zip": "L4T1A5",
#     "province": "ON",
#     "phone": "905-965-7800",
#     "url": "https://www.simpleautos.ca",
#     "latitude": "43.701760",
#     "longitude": "-79.645490"
# }

# %%
base_url ='https://www.tabangimotors.com/'
inventory_url = 'https://www.tabangimotors.com/used-cars'

# %%
def parse_inventory(query_args):
    global base_url, inventory_url
    res = []

    time.sleep(1.1)
    response = requests.get(inventory_url, query_args)
    
    soup = BeautifulSoup(response.text, 'lxml')
    vehicles = soup.find_all('div', class_='vehicle search-result-item vehicleList')
    if vehicles is None:
        return res, False
    
    for v in vehicles:
        # check if it isn't sold
        sold = v.find('div', class_='SoldVehicle')
        if sold is not None:
            return res, False # all the rest of the inventory is a list of sold vehicles, no need to go further

        # get vehicle description page url
        url = base_url + v.div.contents[1].div.div.a['href']
        
        # Printing URL (for debugginh purposes)
        print(url)
        res.append(url)
    
    return res, True

# %%
# Making a list of inventory URLs
vehicle_urls = []
cpage = 1

urls, has_more = parse_inventory({'ppage': 100, 'cpage': cpage})

while has_more:
    vehicle_urls.extend(urls)
    cpage += 1
    urls, has_more = parse_inventory({'cpage': cpage})
    
vehicle_urls.extend(urls)
print(len(vehicle_urls))
# Out:
# https://www.tabangimotors.com//cars/used/2015-Honda-Civic-Sedan-94639
# https://www.tabangimotors.com//cars/used/2016-Volkswagen-Jetta-Sedan-103540
# https://www.tabangimotors.com//cars/used/2017-Ford-Edge-SUV-112015
# https://www.tabangimotors.com//cars/used/2018-Subaru-Outback-SUV-89377
# https://www.tabangimotors.com//cars/used/2013-Nissan-Rogue-SUV-113669
# https://www.tabangimotors.com//cars/used/2013-Ford-Escape-SUV-113677
# https://www.tabangimotors.com//cars/used/2017-Honda-Accord-Sedan-110070
# https://www.tabangimotors.com//cars/used/2015-Nissan-Rogue-SUV-102822
# https://www.tabangimotors.com//cars/used/2018-Ford-Escape-SUV-109248
# https://www.tabangimotors.com//cars/used/2017-Mercedes-Benz-C-Class-Sedan-105611
# https://www.tabangimotors.com//cars/used/2015-Mercedes-Benz-CLA-Class-Sedan-105664
# https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz
# https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-C-Class-Sedan-88633
# https://www.tabangimotors.com//cars/used/2016-Honda-Civic-Sedan-89771
# https://www.tabangimotors.com//cars/used/2015-Volkswagen-Passat-Sedan-83048
# https://www.tabangimotors.com//cars/used/2015-BMW-3-Series-Sedan-88187
# https://www.tabangimotors.com//cars/used/2017-Nissan-Rogue-SUV-88564
# https://www.tabangimotors.com//cars/used/2016-Chevrolet-Cruze-Sedan-87229
# https://www.tabangimotors.com//cars/used/2017-Ford-F-150-Truck-Crew-Cab-76398
# https://www.tabangimotors.com//cars/used/2016-Honda-CR-V-SUV-81395
# https://www.tabangimotors.com//cars/used/2017-Mercedes-Benz-C-Class-Sedan-87227
# https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-CLA-Class-Sedan-87233
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75271
# https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-CLA-Class-Sedan-87222
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75268
# https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-C-Class-Sedan-84354
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75277
# https://www.tabangimotors.com//cars/used/2012-Volkswagen-Passat-Sedan-75293
# https://www.tabangimotors.com//cars/used/2012-Volkswagen-Passat-Sedan-75285
# https://www.tabangimotors.com//cars/used/2017-Mercedes-Benz-CLA-Class-Sedan-81736
# https://www.tabangimotors.com//cars/used/2017-Audi-A4-Sedan-75369
# https://www.tabangimotors.com//cars/used/2012-Volkswagen-Passat-Sedan-75311
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75279
# https://www.tabangimotors.com//cars/used/2014-Volkswagen-Passat-Sedan-75269
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75296
# https://www.tabangimotors.com//cars/used/2012-Volkswagen-Passat-Sedan-75292
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75315
# https://www.tabangimotors.com//cars/used/2013-Volkswagen-Passat-Sedan-75339
# https://www.tabangimotors.com//cars/used/2014-Volkswagen-Passat-Sedan-75376
# https://www.tabangimotors.com//cars/used/2015-BMW-3-Series-Sedan-75204
# https://www.tabangimotors.com//cars/used/2016-Ford-Edge-SUV-75185
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ce3dcbdaf99f> in <module>
#       8     vehicle_urls.extend(urls)
#       9     cpage += 1
# ---> 10     urls, has_more = parse_inventory({'cpage': cpage})
#      11
#      12 vehicle_urls.extend(urls)
#
# <ipython-input-3-d424b3bfb9a9> in parse_inventory(query_args)
#       4
#       5     time.sleep(1.1)
# ----> 6     response = requests.get(inventory_url, query_args)
#       7
#       8     soup = BeautifulSoup(response.text, 'lxml')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
# Function parses vehicle description page and returns a dictionary with its parameters
def parse_car_infopage(url):
    # Translation table from their names to our key names
    translation_table = {
        'Make:': 'make',
        'Model:': 'model',
        'Year:': 'year',
        'Body Style:': 'body_style',
        'Odometer:': 'mileage', # Note: special treatment
        'Transmission:': 'transmission',
        'Engine:': 'cylinders', # Note: special treatment
        'Engine Size:': 'displacement',
        'Driveline:': 'drivetrain',
        'Exterior Color:': 'ext_color', 
        'Interior Color:': 'int_color',
        'Doors:': 'doors', # Note: special treatment
        'Passengers:': 'passengers',
        'Stock Number:': 'stock_id',
        'VIN:': 'vin'
    }
    
    # Fetching the page
    time.sleep(1.1)
    response = requests.get(url)

    # Parsing
    soup = BeautifulSoup(response.text, 'lxml')
    price_node = soup.find('span', class_='PriceValue')
    details_node = soup.find('div', class_='VehicleInfoDetails')
    descr_node = soup.find('div', class_='seller_comments')
    features_node = soup.find('ul', class_='VehicleOptions')

    # Basic info
    res = {
        'timestamp': dt.datetime.now().isoformat(),
        'dealer': 'tabangimotors',
        'url': url
    }

    # Price
    price = re.sub('[^0-9]', '', price_node.contents[0]) # Cleaning junk, leaving only numbers
    res['price'] = price

    # Reading core parameters
    spans = details_node.find_all('span')

    for s in spans:
        if s.text in translation_table:
            key = translation_table[s.text]
            value = s.next_sibling.text

            # Ad Hoc treatment
            if key in ['cylinders', 'doors']:
                value = value.split()[0]
            elif key == 'mileage':
                value = re.sub('[^0-9]', '', value) # Remove all non numbers using regexp substitution

            res[key] = value
    
    # Free text description        
    res['description'] = descr_node.find('p').text

    # Features and options
    res['features'] = []
    items = features_node.find_all('li')
    for i in items:
        res['features'].append(i.text)
    
    # Printing result (for debugging purposes)
    print(json.dumps(res, indent=4))
    
    # Done
    return res

# %%
# Now scraping vehicle data, one by one
vehicle_data = []

for url in vehicle_urls:
    vehicle_data.append(parse_car_infopage(url))
    
print(len(vehicle_data))

with open('data/tabangimotors_cars.json', 'w', encoding='utf-8') as fp:
    for v in vehicle_data:
        fp.writelines(json.dumps(v) + "\n")
# Out:
# {
#     "timestamp": "2020-04-25T13:23:06.937839",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Honda-Civic-Sedan-94639",
#     "price": "8995",
#     "make": "Honda",
#     "model": "Civic",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "133160",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.8",
#     "drivetrain": "FWD",
#     "ext_color": "Black",
#     "int_color": "Beige",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8283",
#     "vin": "2HGFB2F44FH011289",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:09.002901",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Volkswagen-Jetta-Sedan-103540",
#     "price": "10995",
#     "make": "Volkswagen",
#     "model": "Jetta",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "98651",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.4",
#     "drivetrain": "FWD",
#     "ext_color": "Gray",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8434",
#     "vin": "3VW267AJ5GM208628",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:10.840237",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Ford-Edge-SUV-112015",
#     "price": "15995",
#     "make": "Ford",
#     "model": "Edge",
#     "year": "2017",
#     "body_style": "SUV",
#     "mileage": "139447",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Grey",
#     "int_color": "Beige",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8484",
#     "vin": "2FMPK4J96HBB23028",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:12.720427",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2018-Subaru-Outback-SUV-89377",
#     "price": "15995",
#     "make": "Subaru",
#     "model": "Outback",
#     "year": "2018",
#     "body_style": "SUV",
#     "mileage": "143356",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "AWD",
#     "ext_color": "Gray",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8204",
#     "vin": "4S4BSDAC6J3278500",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:14.548496",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2013-Nissan-Rogue-SUV-113669",
#     "price": "7995",
#     "make": "Nissan",
#     "model": "Rogue",
#     "year": "2013",
#     "body_style": "SUV",
#     "mileage": "167589",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8486",
#     "vin": "JN8AS5MTXDW013264",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "CD Player",
#         "Cruise Control",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:16.329673",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2013-Ford-Escape-SUV-113677",
#     "price": "7995",
#     "make": "Ford",
#     "model": "Escape",
#     "year": "2013",
#     "body_style": "SUV",
#     "mileage": "166341",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.6",
#     "drivetrain": "4WD",
#     "ext_color": "White",
#     "int_color": "Grey",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "6338",
#     "vin": "1FMCU9GX7DUA49103",
#     "description": "-",
#     "features": [
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Daytime Running Lights",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:18.111565",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Honda-Accord-Sedan-110070",
#     "price": "17995",
#     "make": "Honda",
#     "model": "Accord",
#     "year": "2017",
#     "body_style": "Sedan",
#     "mileage": "62282",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.4",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8480",
#     "vin": "1HGCR2F69HA806677",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:19.912084",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Nissan-Rogue-SUV-102822",
#     "price": "11995",
#     "make": "Nissan",
#     "model": "Rogue",
#     "year": "2015",
#     "body_style": "SUV",
#     "mileage": "100096",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8424",
#     "vin": "5N1AT2MT0FC802143",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "Center Arm Rest",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Side Airbag",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:21.705164",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2018-Ford-Escape-SUV-109248",
#     "price": "12995",
#     "make": "Ford",
#     "model": "Escape",
#     "year": "2018",
#     "body_style": "SUV",
#     "mileage": "154954",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.5",
#     "drivetrain": "4WD",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8466",
#     "vin": "1FMCU9GD0JUB76888",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:23.489334",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Mercedes-Benz-C-Class-Sedan-105611",
#     "price": "26995",
#     "make": "Mercedes-Benz",
#     "model": "C-Class",
#     "year": "2017",
#     "body_style": "Sedan",
#     "mileage": "54453",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8456",
#     "vin": "55SWF4KB5HU185351",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Auto Dimming Mirrors",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Tinted Glass",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:25.302058",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Mercedes-Benz-CLA-Class-Sedan-105664",
#     "price": "17995",
#     "make": "Mercedes-Benz",
#     "model": "CLA-Class",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "81463",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8457",
#     "vin": "WDDSJ4GB6FN176055",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Automatic Headlight",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Satellite Radio",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:27.087324",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-CLA-Class-Sedan-101035",
#     "price": "21995",
#     "make": "Mercedes-Benz",
#     "model": "CLA-Class",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "62952",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "FWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8404",
#     "vin": "WDDSJ4EBXGN300882",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Daytime Running Lights",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:28.868790",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Nissan-Rogue-SUV-109253",
#     "price": "13995",
#     "make": "Nissan",
#     "model": "Rogue",
#     "year": "2017",
#     "body_style": "SUV",
#     "mileage": "121980",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8467",
#     "vin": "5N1AT2MV9HC801285",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:30.653748",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Honda-Odyssey-Van-Minivan-99688",
#     "price": "21995",
#     "make": "Honda",
#     "model": "Odyssey",
#     "year": "2016",
#     "body_style": "Van-Minivan",
#     "mileage": "44058",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.5",
#     "drivetrain": "FWD",
#     "ext_color": "Silver",
#     "int_color": "Grey",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8369",
#     "vin": "5FNRL5H40GB504238",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "DVD Player",
#         "Electronic  Stability Control",
#         "Entertainment System",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Sliding Door",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:32.430217",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2013-Volkswagen-Jetta-Sedan-112164",
#     "price": "8995",
#     "make": "Volkswagen",
#     "model": "Jetta",
#     "year": "2013",
#     "body_style": "Sedan",
#     "mileage": "109030",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "9004",
#     "vin": "3VWWL7AJ9DM455091",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Windows",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:34.225302",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Audi-Q5-SUV-110065",
#     "price": "22995",
#     "make": "Audi",
#     "model": "Q5",
#     "year": "2016",
#     "body_style": "SUV",
#     "mileage": "80145",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8479",
#     "vin": "WA1L2AFPXGA116189",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Auto Dimming Mirrors",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Daytime Running Lights",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Folding Rear Seat",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:36.100966",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Honda-Civic-Sedan-88522",
#     "price": "10995",
#     "make": "Honda",
#     "model": "Civic",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "87101",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.8",
#     "drivetrain": "FWD",
#     "ext_color": "Silver",
#     "int_color": "Gray",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8181",
#     "vin": "2HGFB2F54FH040591",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:38.207112",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Volkswagen-Passat-Sedan-101069",
#     "price": "12995",
#     "make": "Volkswagen",
#     "model": "Passat",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "104165",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.8",
#     "drivetrain": "FWD",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8412",
#     "vin": "1VWBS7A38GC019180",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Daytime Running Lights",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:40.067716",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-BMW-3-Series-Sedan-75116",
#     "price": "18995",
#     "make": "BMW",
#     "model": "3 Series",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "62732",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "7649",
#     "vin": "WBA3B3C5XFF548204",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Bluetooth",
#         "CD Player",
#         "Center Arm Rest",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "DVD Player",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rain Sensor Wipers",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:41.862137",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-BMW-3-Series-Sedan-75152",
#     "price": "16995",
#     "make": "BMW",
#     "model": "3 Series",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "81753",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Silver",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "7598",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Center Arm Rest",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "DVD Player",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Memory Seat",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Parking Sensor",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:43.646734",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2008-Audi-Q7-SUV-75123",
#     "price": "9995",
#     "make": "Audi",
#     "model": "Q7",
#     "year": "2008",
#     "body_style": "SUV",
#     "mileage": "179308",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.6",
#     "drivetrain": "AWD",
#     "ext_color": "Gray",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "5",
#     "stock_id": "7614",
#     "vin": "WA1BY64L58D050805",
#     "description": "PUBLIC OFFER BEFORE WHOLESALE - These vehicles fall outside our parameters for retail. A diamond in the rough these offerings tend to be higher mileage older model years or may require some mechanical work to pass safety - Sold as is without warranty - What you see is what you pay plus tax - Available for a limited time. See disclaimer below.",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "Backup Camera",
#         "Bluetooth",
#         "Center Arm Rest",
#         "Cup Holder",
#         "DVD Player",
#         "Electronic  Stability Control",
#         "Folding Rear Seat",
#         "Heated Seats",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Parking Sensor",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rain Sensor Wipers",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Satellite Radio",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer",
#         "Xenon Headlights"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:45.434864",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Volkswagen-Jetta-Sedan-110047",
#     "price": "9995",
#     "make": "Volkswagen",
#     "model": "Jetta",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "98615",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.4",
#     "drivetrain": "FWD",
#     "ext_color": "Blue",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8475",
#     "vin": "3VW267AJ5GM254444",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:47.282911",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Honda-Odyssey-Van-Minivan-110072",
#     "price": "23995",
#     "make": "Honda",
#     "model": "Odyssey",
#     "year": "2017",
#     "body_style": "Van-Minivan",
#     "mileage": "26571",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.5",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Grey",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8481",
#     "vin": "5FNRL5H28HB501328",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:49.309343",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2009-Mazda-MAZDA5-Van-Minivan-111322",
#     "price": "4995",
#     "make": "Mazda",
#     "model": "MAZDA5",
#     "year": "2009",
#     "body_style": "Van-Minivan",
#     "mileage": "193850",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.3",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8483",
#     "vin": "JM1CR293390352594",
#     "description": "PUBLIC OFFER BEFORE WHOLESALE - These vehicles fall outside our parameters for retail. A diamond in the rough these offerings tend to be higher mileage older model years or may require some mechanical work to pass safety - Sold as is without warranty - What you see is what you pay plus tax - Available for a limited time. See disclaimer below.",
#     "features": [
#         "3rd Row Seating",
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "Child-Safety Locks",
#         "Climate Control",
#         "Cruise Control",
#         "Digital Clock",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:51.145374",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2018-Acura-RDX-SUV-109269",
#     "price": "22995",
#     "make": "Acura",
#     "model": "RDX",
#     "year": "2018",
#     "body_style": "SUV",
#     "mileage": "114159",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.5",
#     "drivetrain": "AWD",
#     "ext_color": "Silver",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8470",
#     "vin": "5J8TB4H54JL801756",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "Child-Safety Locks",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Folding Rear Seat",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:52.953117",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Nissan-Rogue-SUV-109263",
#     "price": "14995",
#     "make": "Nissan",
#     "model": "Rogue",
#     "year": "2017",
#     "body_style": "SUV",
#     "mileage": "116741",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8468",
#     "vin": "5N1AT2MV7HC736419",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Folding Rear Seat",
#         "Heated Exterior Mirrors",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:54.727747",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Hyundai-Elantra-Sedan-110045",
#     "price": "13995",
#     "make": "Hyundai",
#     "model": "Elantra",
#     "year": "2017",
#     "body_style": "Sedan",
#     "mileage": "40301",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8474",
#     "vin": "KMHD84LF8HU381016",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "Center Arm Rest",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:56.565239",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Volkswagen-Jetta-Sedan-103253",
#     "price": "10995",
#     "make": "Volkswagen",
#     "model": "Jetta",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "74044",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.4",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8430",
#     "vin": "3VW267AJ2GM263599",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:23:58.427691",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2013-Mazda-MAZDA3-Sedan-93731",
#     "price": "6995",
#     "make": "Mazda",
#     "model": "MAZDA3",
#     "year": "2013",
#     "body_style": "Sedan",
#     "mileage": "126619",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "FWD",
#     "ext_color": "Silver",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8280",
#     "vin": "JM1BL1UF4D1771789",
#     "description": "-",
#     "features": [
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "CD Player",
#         "Climate Control",
#         "Cup Holder",
#         "Electronic  Stability Control",
#         "Entertainment System",
#         "Folding Rear Seat",
#         "Keyless Entry",
#         "Low Tire Pressure Warning",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:24:00.258158",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Jeep-Grand-Cherokee-SUV-109243",
#     "price": "30995",
#     "make": "Jeep",
#     "model": "Grand Cherokee",
#     "year": "2017",
#     "body_style": "SUV",
#     "mileage": "92975",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.6",
#     "drivetrain": "4WD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8464",
#     "vin": "1C4RJFJG6HC938789",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Auto Dimming Mirrors",
#         "Automatic Headlight",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rain Sensor Wipers",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:24:02.140800",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Ford-Explorer-SUV-109504",
#     "price": "22995",
#     "make": "Ford",
#     "model": "Explorer",
#     "year": "2016",
#     "body_style": "SUV",
#     "mileage": "118300",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.5",
#     "drivetrain": "4WD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8471",
#     "vin": "1FM5K8D82GGA53729",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
# ...
#     "price": "19995",
#     "make": "Audi",
#     "model": "Q5",
#     "year": "2016",
#     "body_style": "SUV",
#     "mileage": "72253",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Gray",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8439",
#     "vin": "WA1C2AFP9GA051321",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Rear Windows Wiper",
#         "Remote Trunk Release",
#         "Satellite Radio",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:26:58.083495",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Volkswagen-Golf-Sedan-103547",
#     "price": "9995",
#     "make": "Volkswagen",
#     "model": "Golf",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "137267",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "1.8",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8435",
#     "vin": "3VW217AU9GM043871",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Automatic Headlight",
#         "Backup Camera",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:00.090580",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Honda-Odyssey-Van-Minivan-109267",
#     "price": "16995",
#     "make": "Honda",
#     "model": "Odyssey",
#     "year": "2015",
#     "body_style": "Van-Minivan",
#     "mileage": "161061",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.5",
#     "drivetrain": "FWD",
#     "ext_color": "Blue",
#     "int_color": "Beige",
#     "doors": "4",
#     "passengers": "8",
#     "stock_id": "8469",
#     "vin": "5FNRL5H64FB509152",
#     "description": "-",
#     "features": [
#         "3rd Row Seating",
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Automatic Headlight",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "DVD Player",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Sliding Door",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:01.985925",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Audi-Q7-SUV-98091",
#     "price": "25995",
#     "make": "Audi",
#     "model": "Q7",
#     "year": "2015",
#     "body_style": "SUV",
#     "mileage": "117430",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8326",
#     "vin": "WA1WMCFE5FD009047",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Auto Dimming Mirrors",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Memory Seat",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:03.811474",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-CLA-Class-Sedan-103035",
#     "price": "21995",
#     "make": "Mercedes-Benz",
#     "model": "CLA-Class",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "53473",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Silver",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8426",
#     "vin": "WDDSJ4GB0GN366645",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Automatic Headlight",
#         "Bluetooth",
#         "Center Arm Rest",
#         "Child-Safety Locks",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Memory Seat",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Traction Control",
#         "Trip Odometer",
#         "Vehicle Anti-Theft System"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:05.709920",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2018-Nissan-Rogue-SUV-101056",
#     "price": "18800",
#     "make": "Nissan",
#     "model": "Rogue",
#     "year": "2018",
#     "body_style": "SUV",
#     "mileage": "31523",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.5",
#     "drivetrain": "FWD",
#     "ext_color": "White",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8409",
#     "vin": "5N1AT2MT3JC726166",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:07.538147",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2017-Audi-Q7-SUV-103061",
#     "price": "33800",
#     "make": "Audi",
#     "model": "Q7",
#     "year": "2017",
#     "body_style": "SUV",
#     "mileage": "90488",
#     "transmission": "Automatic",
#     "cylinders": "6",
#     "displacement": "3.0",
#     "drivetrain": "AWD",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8427",
#     "vin": "WA1AAAF72HD046570",
#     "description": "-",
#     "features": [
#         "3rd Row Seating",
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Backup Camera",
#         "Bluetooth",
#         "CD Player",
#         "Child-Safety Locks",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Memory Seat",
#         "Navigation System",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Satellite Radio",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer",
#         "Vehicle Anti-Theft System"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:09.724461",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-BMW-3-Series-Sedan-86104",
#     "price": "15995",
#     "make": "BMW",
#     "model": "3 Series",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "83756",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Silver",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8105",
#     "vin": "WBA8E5G5XGNT93664",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Automatic Headlight",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Parking Sensor",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:11.596381",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2015-Mercedes-Benz-CLA-Class-Sedan-101050",
#     "price": "19995",
#     "make": "Mercedes-Benz",
#     "model": "CLA-Class",
#     "year": "2015",
#     "body_style": "Sedan",
#     "mileage": "77345",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Grey",
#     "int_color": "White",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8408",
#     "vin": "WDDSJ4GB1FN275544",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Bluetooth",
#         "CD Player",
#         "Climate Control",
#         "Cruise Control",
#         "Cup Holder",
#         "Daytime Running Lights",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Dual impact Airbags",
#         "Electronic  Stability Control",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Navigation System",
#         "Parking Sensor",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Sunroof/Moonroof",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
# {
#     "timestamp": "2020-04-25T13:27:13.545207",
#     "dealer": "tabangimotors",
#     "url": "https://www.tabangimotors.com//cars/used/2016-Mercedes-Benz-C-Class-Sedan-102814",
#     "price": "20995",
#     "make": "Mercedes-Benz",
#     "model": "C-Class",
#     "year": "2016",
#     "body_style": "Sedan",
#     "mileage": "95569",
#     "transmission": "Automatic",
#     "cylinders": "4",
#     "displacement": "2.0",
#     "drivetrain": "AWD",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "doors": "4",
#     "passengers": "-",
#     "stock_id": "8423",
#     "vin": "55SWF4KBXGU157690",
#     "description": "-",
#     "features": [
#         "ABS Brakes",
#         "Air Conditioning",
#         "Alloy Wheels",
#         "AM/FM Stereo",
#         "Auto Dimming Mirrors",
#         "Bluetooth",
#         "CD Player",
#         "Cruise Control",
#         "Cup Holder",
#         "Digital Clock",
#         "Driver Side Airbag",
#         "Electronic  Stability Control",
#         "Fog Lights",
#         "Heated Exterior Mirrors",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather Seats",
#         "Leather Steering Wheels",
#         "Low Tire Pressure Warning",
#         "Multi-Zone A/C",
#         "Passenger Airbag",
#         "Power Brakes",
#         "Power Locks",
#         "Power Mirrors",
#         "Power Seat",
#         "Power Steering",
#         "Power Windows",
#         "Power-Assist Disc Brakes",
#         "Premium Audio",
#         "Rear Window Defroster",
#         "Remote Trunk Release",
#         "Security System",
#         "Side Airbag",
#         "Tilt Steering",
#         "Traction Control",
#         "Trip Odometer"
#     ]
# }
