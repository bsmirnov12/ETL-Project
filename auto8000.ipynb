# %%
# UT-TOR-DATA-PT-01-2020-U-C Week 12
# ETL Project
# Scraping http://www.leopardmotors.ca/inventory/
# (c) Boris Smirnov

# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup
import json
import time
import datetime as dt
import re

# %%
# Global constants
dealer_name = 'auto8000'
dealer_json = 'data/' + dealer_name + '.json'
dealer_cars_json = 'data/' + dealer_name + '_cars.json'
base_url = 'https://www.auto8000.ca'
inventory_url = base_url + '/inventory/'

# %%
# Dealers description
dealer_dct = {
    'id': dealer_name,
    'name': 'Auto 8000 Wholesaler & Services Inc.',
    'street': '260 Dundas St. West',
    'city': 'Mississauga',
    'zip': 'L5B1J2',
    'province': 'ON',
    'phone': '(905) 566-7888',
    'url': base_url,
    'latitude': '43.574655',
    'longitude': '-79.622358',
}

print(json.dumps(dealer_dct, indent=4))

with open(dealer_json, 'w', encoding='utf-8') as fp:
    fp.writelines(json.dumps(dealer_dct) + "\n")
# Out:
# {
#     "id": "auto8000",
#     "name": "Auto 8000 Wholesaler & Services Inc.",
#     "street": "260 Dundas St. West",
#     "city": "Mississauga",
#     "zip": "L5B1J2",
#     "province": "ON",
#     "phone": "(905) 566-7888",
#     "url": "https://www.auto8000.ca",
#     "latitude": "43.574655",
#     "longitude": "-79.622358"
# }

# %%
# Open inventory in separate automated browser window
browser = Browser('chrome', executable_path='chromedriver.exe', headless=False)
browser.visit(inventory_url)

# %%
# Working around Infinite Scroll
# The strategy:
#    scroll down with JavaScript to the bottom of the page,
#    Infinite Scroll will load some items
#    count the items
#    repeat until number of items on the page doesn't change
# https://towardsdatascience.com/elevate-your-webscraping-with-splinter-a926eee7f7d9
scrollJS = "window.scroll({top: document.body.scrollHeight, left: 0, behavior: 'smooth'});"
browser.execute_script(scrollJS) # this first scroll doesn't load new items

soup = BeautifulSoup(browser.html, 'lxml')
inventory_nodes = soup.find_all('li', class_='inventory-item')
new_inv_count = len(inventory_nodes)
inventory_count = 0

while inventory_count < new_inv_count:
    print(f"Number of cars on the inventory page: {new_inv_count} (was {inventory_count})")
    inventory_count = new_inv_count
    time.sleep(1)
    browser.execute_script(scrollJS)
    soup = BeautifulSoup(browser.html, 'lxml')
    inventory_nodes = soup.find_all('li', class_='inventory-item')
    new_inv_count = len(inventory_nodes)

# At this point we should have complete list of the inventory cars in inventory_nodes
# Next step: scraping URLs of car pages
# Out:
# Number of cars on the inventory page: 6 (was 0)
# Number of cars on the inventory page: 12 (was 6)
# Number of cars on the inventory page: 18 (was 12)
# Number of cars on the inventory page: 24 (was 18)
# Number of cars on the inventory page: 30 (was 24)
# Number of cars on the inventory page: 36 (was 30)
# Number of cars on the inventory page: 42 (was 36)
# Number of cars on the inventory page: 44 (was 42)

# %%
# Build a list URLs to cars' pages
vehicle_urls = []

for node in inventory_nodes:

    onclick = node['onclick']
    url = base_url + onclick.split("'")[1]
    vehicle_urls.append(url)
    # print(url)

print(len(vehicle_urls))
# Out:
# 44

# %%
# Function opens car's web page with browser
# Then uses BeautifulSoup to extract the data
# Returns a dictionaray with car data
# If car data is invalid, returns a dict with key "invalid"
# The data may be invalid if there is no pricing information
def parse_car_infopage(url):

    # Open the page
    time.sleep(3)
    browser.visit(url)
    soup = BeautifulSoup(browser.html, 'lxml')
    
    # Basic info
    res = {
        'timestamp': dt.datetime.now().isoformat(),
        'dealer': dealer_name,
        'url': url
    }

    # Year is in the header
    year_node = soup.find('div', class_='header_title').h1
    s = year_node.text
    res['year'] = s.split(' ', 1)[0]
    
    # Price
    price_node = soup.find('div', class_='offer_price').strong
    s = price_node.text
    price = re.sub('[^0-9]', '', s.split('.')[0])
    if len(price) == 0: # This dealer advertises a car without price information
        res['invalid'] = 'invalid'
    else:
        res['price'] = price
    
    # Translation table from their names to our key names
    translation_table = {
        'Stock #:': 'stock_id',
        'Make:': 'make',
        'Model:': 'model',
        'Trim:': 'submodel',
        'Odometer:': 'mileage', # Note: special treatment
        'Drivetrain:': 'drivetrain', # Note: special treatment
        'Body type:': 'body_style',
        'Engine:': 'cylinders', # Note: special treatment
        'Transmission:': 'transmission',
        'Doors:': 'doors',
        'Passengers:': 'passengers',
        'Exterior color:': 'ext_color', # can be Unknown
        'Interior color:': 'int_color', # can be Unknown

        # These arn't in the specs
        'Year:': 'year',
        'Engine Size:': 'displacement',
        'VIN Number:': 'vin'
    }

    drivetrain_vocabulary = {
        'Rear Wheel Drive': 'RWD',
        'Front Wheel Drive': 'FWD',
        'All Wheel Drive': 'AWD',
    }
    
    specs_nodes = soup.find('div', class_="offer_specification").find_all('li')
    for li in specs_nodes:
        if li.span.text in translation_table:
            key = translation_table[li.span.text]
            value = li.strong.text

            # Ad Hoc treatment
            if key in ['mileage', 'cylinders']:
                value = re.sub('[^0-9]', '', value) # Remove all non numbers using regexp substitution
            elif key in ['ext_color', 'int_color'] and value == 'Unknown':
                key = ''
            elif key == 'drivetrain':
                if value in drivetrain_vocabulary:
                    value = drivetrain_vocabulary[value]
                
            if len(key) > 0:
                res[key] = value
        
    
    # Features and options
    features_nodes = soup.find('div', id='t_overview').ul.find_all('li')
    res['features'] = []
    for li in features_nodes:
        res['features'].append(li.text)

    # Printing result (for debugging purposes)
    print(json.dumps(res, indent=4))
    
    # Done
    return res

# %%
# Scraping cars
vehicle_data = []

for url in vehicle_urls:
    result = parse_car_infopage(url)
    if 'invalid' not in result:
        vehicle_data.append(result)

# Done
browser.quit()
print(len(vehicle_data))

with open(dealer_cars_json, 'w', encoding='utf-8') as fp:
    for v in vehicle_data:
        fp.writelines(json.dumps(v) + "\n")
# Out:
# {
#     "timestamp": "2020-04-25T22:42:07.915185",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2593/2000-honda-accord",
#     "year": "2000",
#     "invalid": "invalid",
#     "stock_id": "HO001",
#     "make": "Honda",
#     "model": "Accord",
#     "submodel": "EX-V6",
#     "mileage": "130000",
#     "drivetrain": "FWD",
#     "body_style": "Coupe",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:11.516725",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2591/2015-audi-q5",
#     "year": "2015",
#     "price": "20990",
#     "stock_id": "AU101",
#     "make": "Audi",
#     "model": "Q5",
#     "submodel": "2.0T Premium Plus",
#     "mileage": "140001",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "Cruise Control",
#         "Fog Lights",
#         "Heated Mirrors",
#         "Heated Seats",
#         "Leather",
#         "Memory Seat",
#         "Navigation",
#         "Panoramic Roof",
#         "Power Driver Seat",
#         "Power Liftgate",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Traction Control",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:15.097231",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2592/2017-nissan-sentra",
#     "year": "2017",
#     "price": "13990",
#     "stock_id": "NI078",
#     "make": "Nissan",
#     "model": "Sentra",
#     "submodel": "SV",
#     "mileage": "71019",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "CD/MP3",
#         "Cloth Interior",
#         "Cruise Control",
#         "Floor Mats",
#         "Heated Seats",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Sunroof",
#         "Tilt Wheel",
#         "Traction Control",
#         "USB Input",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:18.680231",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2588/2011-kia-sorento",
#     "year": "2011",
#     "price": "8990",
#     "stock_id": "KI048",
#     "make": "Kia",
#     "model": "Sorento",
#     "submodel": "LX",
#     "mileage": "147388",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "7",
#     "ext_color": "Cream",
#     "int_color": "Beige",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "Carproof Clean",
#         "Cloth Interior",
#         "Cruise Control",
#         "Fog Lights",
#         "Heated Seats",
#         "No Accident",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:21.973757",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2584/2013-hyundai-elantra",
#     "year": "2013",
#     "price": "8990",
#     "stock_id": "HY045",
#     "make": "Hyundai",
#     "model": "Elantra",
#     "submodel": "GLS/GLS Preferred/ Limited/Limited Tech GS/SE/SE Tech",
#     "mileage": "137857",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Brown",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "CD/MP3",
#         "Cruise Control",
#         "Heated Seats",
#         "Leather",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Traction Control",
#         "USB Input",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:25.268303",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2583/2014-nissan-nv",
#     "year": "2014",
#     "price": "21990",
#     "stock_id": "NI066",
#     "make": "Nissan",
#     "model": "NV",
#     "submodel": "1500/2500/3500",
#     "mileage": "121958",
#     "drivetrain": "FWD",
#     "body_style": "Cargo Van",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "3",
#     "passengers": "2",
#     "ext_color": "White",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:28.565811",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2581/2010-ford-e-350",
#     "year": "2010",
#     "price": "11990",
#     "stock_id": "FO085",
#     "make": "Ford",
#     "model": "E-350",
#     "submodel": "Econoline/E-series",
#     "mileage": "152816",
#     "drivetrain": "RWD",
#     "body_style": "Wagon",
#     "cylinders": "8",
#     "transmission": "Automatic",
#     "doors": "3",
#     "passengers": "12",
#     "ext_color": "Silver",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Traction Control"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:32.115749",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2578/2010-ford-e-350",
#     "year": "2010",
#     "invalid": "invalid",
#     "stock_id": "FO084",
#     "make": "Ford",
#     "model": "E-350",
#     "submodel": "Econoline/E-series",
#     "mileage": "1",
#     "drivetrain": "RWD",
#     "body_style": "Cargo Van",
#     "cylinders": "8",
#     "transmission": "Automatic",
#     "doors": "3",
#     "passengers": "2",
#     "ext_color": "White",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:35.672205",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2579/2007-suzuki-sx4",
#     "year": "2007",
#     "invalid": "invalid",
#     "stock_id": "SU122",
#     "make": "Suzuki",
#     "model": "SX4",
#     "submodel": "Base",
#     "mileage": "133000",
#     "drivetrain": "AWD",
#     "body_style": "Hatchback",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Cloth Interior"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:39.232121",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2561/2012-ford-e-350",
#     "year": "2012",
#     "price": "15990",
#     "stock_id": "FO113",
#     "make": "Ford",
#     "model": "E-350",
#     "submodel": "Econoline/E-series",
#     "mileage": "136594",
#     "drivetrain": "FWD",
#     "body_style": "Wagon",
#     "cylinders": "8",
#     "transmission": "Automatic",
#     "doors": "2",
#     "passengers": "15",
#     "ext_color": "White",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "CD/MP3",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Power Lock",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Tilt Wheel",
#         "Traction Control",
#         "Trailer Hitch"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:42.535376",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2572/2015-nissan-rogue",
#     "year": "2015",
#     "price": "14990",
#     "stock_id": "NI072",
#     "make": "Nissan",
#     "model": "Rogue",
#     "submodel": "SV",
#     "mileage": "113051",
#     "drivetrain": "FWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cloth Interior",
#         "Cruise Control",
#         "Heated Mirrors",
#         "Heated Seats",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Sunroof",
#         "Tilt Wheel",
#         "Traction Control"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:45.819064",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2575/2013-smart-fortwo",
#     "year": "2013",
#     "price": "5990",
#     "stock_id": "SM121",
#     "make": "smart",
#     "model": "fortwo",
#     "submodel": "pure coupe",
#     "mileage": "1",
#     "drivetrain": "RWD",
#     "body_style": "Coupe",
#     "cylinders": "3",
#     "transmission": "Automatic",
#     "doors": "2",
#     "passengers": "2",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "Leather"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:49.332864",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2565/2013-smart-fortwo",
#     "year": "2013",
#     "price": "5990",
#     "stock_id": "SM119",
#     "make": "smart",
#     "model": "fortwo",
#     "submodel": "pure coupe",
#     "mileage": "65000",
#     "drivetrain": "RWD",
#     "body_style": "Coupe",
#     "cylinders": "3",
#     "transmission": "Automatic",
#     "doors": "2",
#     "passengers": "2",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Keyless Entry",
#         "Leather",
#         "Power Lock",
#         "Power Windows"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:52.655906",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2576/2014-smart-fortwo",
#     "year": "2014",
#     "price": "6990",
#     "stock_id": "SM114",
#     "make": "smart",
#     "model": "fortwo",
#     "submodel": "pure coupe",
#     "mileage": "34890",
#     "drivetrain": "RWD",
#     "body_style": "Coupe",
#     "cylinders": "3",
#     "transmission": "Automatic",
#     "doors": "2",
#     "passengers": "2",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "Leather"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:56.260527",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2566/2016-dodge-grand caravan",
#     "year": "2016",
#     "price": "13990",
#     "stock_id": "DO118",
#     "make": "Dodge",
#     "model": "Grand Caravan",
#     "submodel": "SE",
#     "mileage": "104566",
#     "drivetrain": "FWD",
#     "body_style": "Minivan",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "7",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Keyless Entry",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:42:59.582149",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2570/2014-nissan-altima",
#     "year": "2014",
#     "price": "10990",
#     "stock_id": "NI070",
#     "make": "Nissan",
#     "model": "Altima",
#     "submodel": "2.5 SV",
#     "mileage": "117423",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cloth Interior",
#         "Keyless Entry",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:02.903398",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2564/2015-honda-cr-v",
#     "year": "2015",
#     "price": "18990",
#     "stock_id": "HO005",
#     "make": "Honda",
#     "model": "CR-V",
#     "submodel": "EX",
#     "mileage": "100092",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cloth Interior",
#         "Cruise Control",
#         "Heated Seats",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Sunroof",
#         "Tilt Wheel"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:06.498492",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2560/2013-hyundai-sonata",
#     "year": "2013",
#     "price": "11590",
#     "stock_id": "HY047",
#     "make": "Hyundai",
#     "model": "Sonata",
#     "submodel": "Limited",
#     "mileage": "108967",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Cruise Control",
#         "Dual Climate Control",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:10.090929",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2571/2008-jeep-patriot",
#     "year": "2008",
#     "price": "1990",
#     "stock_id": "JE111",
#     "make": "Jeep",
#     "model": "Patriot",
#     "submodel": "Base",
#     "mileage": "233615",
#     "drivetrain": "Unknown",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Dark Blue",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:13.410559",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2562/2012-mitsubishi-rvr",
#     "year": "2012",
#     "price": "9990",
#     "stock_id": "MI116",
#     "make": "Mitsubishi",
#     "model": "RVR",
#     "submodel": "SE",
#     "mileage": "117233",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Heated Seats",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel",
#         "Traction Control",
#         "USB Input",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:17.004828",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2558/2015-mitsubishi-lancer",
#     "year": "2015",
#     "price": "9990",
#     "stock_id": "MI117",
#     "make": "Mitsubishi",
#     "model": "Lancer",
#     "submodel": "SE",
#     "mileage": "125384",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "Cruise Control",
#         "Floor Mats",
#         "Heated Seats",
#         "Leather",
#         "Power Lock",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Tilt Wheel",
#         "Traction Control",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:20.610563",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2559/2014-chevrolet-cruze",
#     "year": "2014",
#     "price": "11990",
#     "stock_id": "CH087",
#     "make": "Chevrolet",
#     "model": "Cruze",
#     "submodel": "2LT",
#     "mileage": "95303",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Blue",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cruise Control",
#         "Keyless Entry",
#         "Leather",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:24.160918",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2549/2015-ford-escape",
#     "year": "2015",
#     "price": "16990",
#     "stock_id": "FO115",
#     "make": "Ford",
#     "model": "Escape",
#     "submodel": "Titanium",
#     "mileage": "88011",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cruise Control",
#         "Heated Seats",
#         "Leather",
#         "Navigation",
#         "Panoramic Roof",
#         "Power Driver Seat",
#         "Power Liftgate",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:27.724314",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2546/2013-honda-accord",
#     "year": "2013",
#     "price": "14990",
#     "stock_id": "HO013",
#     "make": "Honda",
#     "model": "Accord",
#     "submodel": "EX-L",
#     "mileage": "133882",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:31.051752",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2529/2010-dodge-grand caravan",
#     "year": "2010",
#     "price": "6999",
#     "stock_id": "DO091",
#     "make": "Dodge",
#     "model": "Grand Caravan",
#     "submodel": "SE",
#     "mileage": "203776",
#     "drivetrain": "FWD",
#     "body_style": "SUV",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "7",
#     "ext_color": "Red",
#     "int_color": "Black",
#     "features": [
#         "Carproof Clean",
#         " No Accident",
#         " Air Conditioning",
#         "AM/FM/CD",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Cloth Interior"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:34.662209",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2543/2016-audi-a4",
#     "year": "2016",
#     "price": "19990",
#     "stock_id": "AU094",
#     "make": "Audi",
#     "model": "A4",
#     "submodel": "S-Line",
#     "mileage": "106606",
#     "drivetrain": "AWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:38.213967",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2540/2014-ford-escape",
#     "year": "2014",
#     "price": "12990",
#     "stock_id": "FO086",
#     "make": "Ford",
#     "model": "Escape",
#     "submodel": "SE",
#     "mileage": "122819",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Heated Seats",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Traction Control"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:41.786402",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2528/2011-chevrolet-equinox",
#     "year": "2011",
#     "price": "8990",
#     "stock_id": "CH089",
#     "make": "Chevrolet",
#     "model": "Equinox",
#     "submodel": "LT",
#     "mileage": "151746",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Dark Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "Cloth Interior",
#         "Cruise Control",
#         "Keyless Entry",
#         "Power Windows"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:45.375116",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2505/2016-chevrolet-cruze",
#     "year": "2016",
#     "price": "14590",
#     "stock_id": "CH088",
#     "make": "Chevrolet",
#     "model": "Cruze",
#     "submodel": "Limited",
#     "mileage": "85893",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "Cruise Control",
#         "Leather",
#         "No Accident",
#         "Power Moonroof",
#         "Rear View Camera"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:48.959135",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2518/2011-honda-accord",
#     "year": "2011",
#     "price": "9990",
#     "stock_id": "HO009",
#     "make": "Honda",
#     "model": "Accord",
#     "submodel": "EX",
#     "mileage": "160006",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "CD/MP3",
#         "Cloth Interior",
#         "Cruise Control",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:52.260423",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2522/2012-toyota-sienna",
#     "year": "2012",
#     "price": "16990",
#     "stock_id": "TO022",
#     "make": "Toyota",
#     "model": "Sienna",
#     "submodel": "XLE",
#     "mileage": "155221",
#     "drivetrain": "FWD",
#     "body_style": "Minivan",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "8",
#     "ext_color": "Silver",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:55.849725",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2513/2015-hyundai-sonata",
#     "year": "2015",
#     "price": "14990",
#     "stock_id": "HY044",
#     "make": "Hyundai",
#     "model": "Sonata",
#     "submodel": "Sport",
#     "mileage": "113177",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Blue",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "Carproof Clean",
#         "Cruise Control",
#         "Dual Climate Control",
#         "Floor Mats",
#         "Heated Seats",
#         "Jack Assembly",
#         "Leather",
#         "No Accident",
#         "Panoramic Roof",
#         "Power Brakes",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:43:59.424584",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2501/2011-ford-escape",
#     "year": "2011",
#     "price": "10990",
#     "stock_id": "FO092",
#     "make": "Ford",
#     "model": "Escape",
#     "submodel": "Limited",
#     "mileage": "101971",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "Cruise Control",
#         "Fog Lights",
#         "Heated Mirrors",
#         "Heated Seats",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Roof Rack",
#         "Tilt Wheel",
#         "Traction Control"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:02.762277",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2496/2014-toyota-camry",
#     "year": "2014",
#     "price": "16590",
#     "stock_id": "TO028",
#     "make": "Toyota",
#     "model": "Camry",
#     "submodel": "SE",
#     "mileage": "90543",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Heated Seats",
#         "Keyless Entry",
#         "Leather",
#         "Navigation",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:06.093508",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2497/2012-hyundai-veracruz",
#     "year": "2012",
#     "price": "9590",
#     "stock_id": "HY051",
#     "make": "Hyundai",
#     "model": "Veracruz",
#     "submodel": "GLS",
#     "mileage": "180112",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "7",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Keyless Entry",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:09.720603",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2499/2015-chevrolet-cruze",
#     "year": "2015",
#     "price": "12590",
#     "stock_id": "CH090",
#     "make": "Chevrolet",
#     "model": "Cruze",
#     "submodel": "2LT",
#     "mileage": "120620",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Blue",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "CD/MP3",
#         "Cruise Control",
#         "Floor Mats",
#         "Heated Seats",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Satellite Radio Sirius",
#         "Tilt Wheel",
#         "Traction Control",
#         "USB Input"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:13.272376",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2488/2015-nissan-altima",
#     "year": "2015",
#     "price": "14990",
#     "stock_id": "NI075",
#     "make": "Nissan",
#     "model": "Altima",
#     "submodel": "2.5 SV",
#     "mileage": "59101",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Bluetooth",
#         "Cloth Interior",
#         "Cruise Control",
#         "Heated Seats",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel",
#         "Traction Control"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:16.606080",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2475/2016-hyundai-elantra",
#     "year": "2016",
#     "price": "11990",
#     "stock_id": "HY043",
#     "make": "Hyundai",
#     "model": "Elantra",
#     "submodel": "Sport",
#     "mileage": "65049",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Silver",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Heated Seats",
#         "Jack Assembly",
#         "Power Brakes",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "USB Input"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:20.298355",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2465/2013-mercedes-benz-c-class",
#     "year": "2013",
#     "price": "16990",
#     "stock_id": "ME109",
#     "make": "Mercedes-Benz",
#     "model": "C-Class",
#     "submodel": "C300",
#     "mileage": "90976",
#     "drivetrain": "AWD",
#     "body_style": "Sedan",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "White",
#     "int_color": "Beige",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Bluetooth",
#         "CD/MP3",
#         "Cruise Control",
#         "Fog Lights",
#         "Heated Seats",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel",
#         "Traction Control",
#         "USB Input",
#         "Voice Command Recognition"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:23.874398",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2456/2012-honda-civic",
#     "year": "2012",
#     "price": "8590",
#     "stock_id": "HO006",
#     "make": "Honda",
#     "model": "Civic",
#     "submodel": "EX",
#     "mileage": "156486",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Steering",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:27.198464",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2418/2012-canam-outlander",
#     "year": "2012",
#     "price": "8990",
#     "stock_id": "CA120",
#     "make": "Canam",
#     "model": "Outlander",
#     "submodel": "1000 XT",
#     "mileage": "8247",
#     "drivetrain": "AWD",
#     "body_style": "Unknown",
#     "cylinders": "",
#     "transmission": "Automatic",
#     "doors": "0",
#     "passengers": "1",
#     "ext_color": "Black",
#     "int_color": "Black",
#     "features": []
# }
# {
#     "timestamp": "2020-04-25T22:44:30.775829",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2417/2013-toyota-camry",
#     "year": "2013",
#     "price": "14990",
#     "stock_id": "TO025",
#     "make": "Toyota",
#     "model": "Camry",
#     "submodel": "LE",
#     "mileage": "98446",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Black",
#     "int_color": "Grey",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Backup Camera",
#         "Cloth Interior",
#         "Cruise Control",
#         "Hard Top",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Steering",
#         "Power Windows",
#         "Tilt Wheel"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:34.463207",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2415/2006-honda-pilot",
#     "year": "2006",
#     "price": "4990",
#     "stock_id": "HO002",
#     "make": "Honda",
#     "model": "Pilot",
#     "submodel": "EX-L",
#     "mileage": "240032",
#     "drivetrain": "AWD",
#     "body_style": "SUV",
#     "cylinders": "6",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Grey",
#     "int_color": "Black",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "CD/MP3",
#         "Cruise Control",
#         "Dual Climate Control",
#         "Foldaway Seating",
#         "Heated Seats",
#         "Leather",
#         "Power Driver Seat",
#         "Power Lock",
#         "Power Mirrors",
#         "Power Moonroof",
#         "Power Windows",
#         "Sunroof"
#     ]
# }
# {
#     "timestamp": "2020-04-25T22:44:38.061018",
#     "dealer": "auto8000",
#     "url": "https://www.auto8000.ca/inventory/vehicle/2321/2013-mazda-mazda6",
#     "year": "2013",
#     "price": "8990",
#     "stock_id": "MA041",
#     "make": "Mazda",
#     "model": "MAZDA6",
#     "submodel": "i Sport",
#     "mileage": "119000",
#     "drivetrain": "FWD",
#     "body_style": "Sedan",
#     "cylinders": "4",
#     "transmission": "Automatic",
#     "doors": "4",
#     "passengers": "5",
#     "ext_color": "Silver",
#     "features": [
#         "Air Conditioning",
#         "AM/FM/CD",
#         "Cloth Interior"
#     ]
# }
# 41
